# %%
import pandas as pd
movies=pd.read_csv("tmdb_5000_movies.csv")
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
import ast

movies["genres"] = movies["genres"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else []
)

# %%
movies_exploded = movies.explode("genres")

# %%
genres_df = pd.json_normalize(movies_exploded["genres"])
genres_count=genres_df.groupby("name")["name"].count()
genres_count= genres_count.reset_index(name="count")
print(genres_count)
# Out:
#                name  count
# 0            Action   1154
# 1         Adventure    790
# 2         Animation    234
# 3            Comedy   1722
# 4             Crime    696
# 5       Documentary    110
# 6             Drama   2297
# 7            Family    513
# 8           Fantasy    424
# 9           Foreign     34
# 10          History    197
# 11           Horror    519
# 12            Music    185
# 13          Mystery    348
# 14          Romance    894
# 15  Science Fiction    535
# 16         TV Movie      8
# 17         Thriller   1274
# 18              War    144
# 19          Western     82

# %%
import matplotlib.pyplot as plt
genres_count.plot.bar(x="name",y="count",xlabel="Genre",ylabel="Number of Movies",title="Number of Movies per Genre",legend=False)
plt.show()
